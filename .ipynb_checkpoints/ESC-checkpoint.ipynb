# %%
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from audiomentations import Compose, AddGaussianNoise, TimeStretch, Gain, PitchShift, RoomSimulator
from tqdm import tqdm
import tensorflow as tf
import IPython.display as ipd
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.16.1
# []

# %%
metadata = pd.read_csv('./ESC-50-master/meta/esc50.csv')
metadata
# Out:
#                filename  fold  target        category  esc10  src_file take
# 0      1-100032-A-0.wav     1       0             dog   True    100032    A
# 1     1-100038-A-14.wav     1      14  chirping_birds  False    100038    A
# 2     1-100210-A-36.wav     1      36  vacuum_cleaner  False    100210    A
# 3     1-100210-B-36.wav     1      36  vacuum_cleaner  False    100210    B
# 4     1-101296-A-19.wav     1      19    thunderstorm  False    101296    A
# ...                 ...   ...     ...             ...    ...       ...  ...
# 1995   5-263831-B-6.wav     5       6             hen  False    263831    B
# 1996  5-263902-A-36.wav     5      36  vacuum_cleaner  False    263902    A
# 1997   5-51149-A-25.wav     5      25       footsteps  False     51149    A
# 1998    5-61635-A-8.wav     5       8           sheep  False     61635    A
# 1999     5-9032-A-0.wav     5       0             dog   True      9032    A
#
# [2000 rows x 7 columns]

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[70], line 3
#       1 device_name = tf.test.gpu_device_name()
#       2 if device_name != '/device:GPU:0':
# ----> 3   raise SystemError('GPU device not found')
#       4 print('Found GPU at: {}'.format(device_name))
#
# SystemError: GPU device not found

# %%
#set aside 20% of images for testing, ensuring that the dataset is balanced by stratified sampling
test_df = metadata.groupby('target', group_keys=False).apply(lambda x: x.sample(8))
train_df = metadata[~metadata.isin(test_df)].dropna()

train_audio = []
train_labels = []
test_audio = []
test_labels = []

for i in tqdm(train_df.index):
  filename = train_df['filename'][i]
  label = train_df['target'][i]
  y,sr = librosa.load('ESC-50-master/audio/'+filename)
  train_audio.append(y)
  train_labels.append(label)

for i in tqdm(test_df.index):
  filename = test_df['filename'][i]
  label = test_df['target'][i]
  file_path = 'C:/Users/MoeSleazy/Downloads/Environmental-Sound-Classification-main/Environmental-Sound-Classification-main/ESC-50-master/audio/' + filename
  y, sr = librosa.load(file_path)  
  test_audio.append(y)
  test_labels.append(label)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1600/1600 [00:02<00:00, 595.24it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 609.76it/s]

# %%
samples = metadata.sample(5)[['filename','category']]
fig, ax = plt.subplots(nrows=5, ncols=5, figsize=(40,40))
for i, idx in enumerate(samples.index):
    #load the audio file and grab the category
    filename = 'C:/Users/MoeSleazy/Downloads/Environmental-Sound-Classification-main/Environmental-Sound-Classification-main/ESC-50-master/audio/'+metadata['filename'][idx]
    category = metadata['category'][idx]
    y, sr = librosa.load(filename)
    #get the melspec in db before plotting
    melspec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    melspec = librosa.power_to_db(melspec, ref=np.max)
    #get the mfccs
    mfcc = librosa.feature.mfcc(y=y,sr=sr,n_fft=2048, hop_length=512, n_mfcc=40)
    #get the tempogram
    oenv = librosa.onset.onset_strength(y=y, sr=sr, hop_length=512)
    tempogram = librosa.feature.tempogram(onset_envelope=oenv, sr=sr, hop_length= 512, norm=None)
    #get the chromagram
    chromagram = librosa.feature.chroma_stft(y=y,sr=sr,n_fft=2048,hop_length=512, n_chroma=24)
    #plot the wave
    librosa.display.waveshow(y,sr=sr,ax=ax[0][i])
    #plot the mfcc
    librosa.display.specshow(mfcc, sr=sr, ax=ax[1][i],y_axis='mel', x_axis='time')
    #plot the melspec
    librosa.display.specshow(melspec,sr=sr,ax=ax[2][i], y_axis='mel', x_axis='time')
    #plot the tempogram
    librosa.display.specshow(tempogram, sr=sr, hop_length=512,x_axis='time', y_axis='tempo',ax=ax[3][i])
    #plot the chromagram
    librosa.display.specshow(chromagram, sr=sr, hop_length=512,x_axis='time', y_axis='chroma',ax=ax[4][i])
    ax[0][i].set_title(f"Raw audio signal | Class: {category} | Shape: {y.shape}",fontsize=20)
    ax[1][i].set_title(f"MFCC | Class: {category} | Shape: {mfcc.T.shape}",fontsize=20)
    ax[2][i].set_title(f"Mel Spec | Class: {category} | Shape: {melspec.T.shape}",fontsize=20)
    ax[3][i].set_title(f"Tempogram | Class: {category} | Shape: {tempogram.T.shape}",fontsize=20)
    ax[4][i].set_title(f"Chromogram | Class: {category} | Shape: {chromagram.T.shape}",fontsize=20)

fig.suptitle('Five different examples, 5 different representations\n\n',fontsize=40)
fig.tight_layout()
fig.savefig('5_examples.png')

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
#callbacks
rlronp=ReduceLROnPlateau(monitor="val_accuracy",factor=0.5, patience=2, verbose=1)
estop=EarlyStopping(monitor="val_accuracy", patience=6, verbose=1, restore_best_weights=True)

def build_model(input_shape):
  # create the model
  model = Sequential()

  # add layers
  model.add(BatchNormalization(axis=1, input_shape=input_shape))
  model.add(Conv2D(64, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(128, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(256, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(256, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(256, activation = 'relu'))
  model.add(Dropout(0.5))
  model.add(Dense(50, activation="softmax"))

  # compile the model
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
def run_experiment(make_spec, augment=0):

  images_train = np.array([make_spec(clip,sr) for clip in train_audio])
  images_test =  np.array([make_spec(clip,sr) for clip in test_audio])

  num_augmented = int(len(train_audio)*augment)
  if augment:
    #genreate augmented images from the first num_augmented clips and concatenate them to the train images
    augmented_img = np.array([make_spec(audio_augment(samples=clip, sample_rate=sr),sr) for clip in train_audio[:num_augmented]])
    images_train = np.concatenate((images_train, augmented_img))


  #expected shape (num_examples, spec freq range, spec time, 1)
  shape_train = (len(images_train), images_train[0].shape[0], images_train[0].shape[1], 1)
  shape_test = (len(images_test), images_train[0].shape[0], images_train[0].shape[1], 1)
  images_train = np.resize(images_train, shape_train)
  images_test = np.resize(images_test, shape_test)

  labels_train = np.array(train_labels+train_labels[:num_augmented])
  labels_test = np.array(test_labels)

  model = build_model(shape_train[1:])

  model.summary()

  history = model.fit(images_train, labels_train, epochs=40, validation_data=(images_test,labels_test), callbacks=[rlronp,estop])

  return history, estop

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#callbacks
rlronp=ReduceLROnPlateau(monitor="val_accuracy",factor=0.5, patience=2, verbose=1)
estop=EarlyStopping(monitor="val_accuracy", patience=8, verbose=1, restore_best_weights=True)

def build_model(input_shape):
  # create the model
  model = Sequential()

  # add layers
  model.add(BatchNormalization(axis=1, input_shape=input_shape))
  model.add(Conv2D(64, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(128, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(256, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(256, kernel_size=3, activation="relu", padding='same'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(256, activation = 'relu'))
  model.add(Dropout(0.5))
  model.add(Dense(50, activation="softmax"))

  # compile the model
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
def plot_curves(history, estop=None):

  fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10))

  ax[0].plot(history.history['accuracy'])
  ax[0].plot(history.history['val_accuracy'])
  ax[0].set_title('Model Accuracy')
  ax[0].set_ylim([0, 1])
  ax[0].set_ylabel('Accuracy')
  ax[0].set_xlabel('Epoch')
  

  ax[1].plot(history.history['loss'])
  ax[1].plot(history.history['val_loss'])
  ax[1].set_title('Model Loss')
  ax[1].set_ylabel('Loss')
  ax[1].set_xlabel('Epoch')

  if estop:
    best_epoch = estop.stopped_epoch-estop.patience
    ax[0].plot(best_epoch, history.history['accuracy'][best_epoch], marker='*', color='gold',ms=10)
    ax[0].plot(best_epoch, history.history['val_accuracy'][best_epoch], marker='*', color='gold',ms=10)
    ax[1].plot(best_epoch, history.history['loss'][best_epoch], marker='*', color='gold',ms=10)
    ax[1].plot(best_epoch, history.history['val_loss'][best_epoch], marker='*', color='gold',ms=10)
    ax[0].legend(['Train', 'Test', 'Best weights'], loc='upper left')
    ax[1].legend(['Train', 'Validation','Best weights'], loc='upper left')
  else:
    ax[0].legend(['Train', 'Test'], loc='upper left')
    ax[1].legend(['Train', 'Validation'], loc='upper left')
  return fig

# %%
# Experiment #1: Mel Spectrograms, No augmentation

def generate_mel_spectrogram(y,sr):
    melspec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    melspec = librosa.power_to_db(melspec, ref=np.max)
    return melspec

#history_ex_1, estop_ex_1 = run_experiment(generate_mel_spectrogram, augment=0)
#plot_curves(history_ex_1, estop=estop_ex_1).show()

# %%
# Train the model and get the history and early stopping callback
history_ex_2, estop_ex_2 = run_experiment(generate_mel_spectrogram, augment=0.25)

# Save the trained model
model_file_path = './model/experiment_2_model.h5'
history_ex_2.model.save(model_file_path)

# Plot training curves (optional)
plot_curves(history_ex_2, estop=estop_ex_2).show()

# Print a message indicating that the model has been saved
print(f"Model saved to: {model_file_path}")
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization_11               │ (None, 128, 216, 1)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_41 (Conv2D)                   │ (None, 128, 216, 64)        │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_40 (MaxPooling2D)      │ (None, 64, 108, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_42 (Conv2D)                   │ (None, 64, 108, 128)        │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_41 (MaxPooling2D)      │ (None, 32, 54, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_43 (Conv2D)                   │ (None, 32, 54, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_42 (MaxPooling2D)      │ (None, 16, 27, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_44 (Conv2D)                   │ (None, 16, 27, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_43 (MaxPooling2D)      │ (None, 8, 13, 256)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_10 (Flatten)                 │ (None, 26624)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 256)                 │       6,816,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 50)                  │          12,850 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,789,106 (29.71 MB)
#  Trainable params: 7,788,850 (29.71 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 828ms/step - accuracy: 0.0417 - loss: 3.8979 - val_accuracy: 0.0200 - val_loss: 4.5932 - learning_rate: 0.0010
# Epoch 2/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 830ms/step - accuracy: 0.1332 - loss: 3.3545 - val_accuracy: 0.1625 - val_loss: 3.2091 - learning_rate: 0.0010
# Epoch 3/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 822ms/step - accuracy: 0.2653 - loss: 2.7171 - val_accuracy: 0.2950 - val_loss: 2.4982 - learning_rate: 0.0010
# Epoch 4/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s
40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 850ms/step - accuracy: 0.9243 - loss: 0.2312 - val_accuracy: 0.6050 - val_loss: 1.9452 - learning_rate: 3.1250e-05
# Epoch 24/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 792ms/step - accuracy: 0.9257 - loss: 0.2281
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 834ms/step - accuracy: 0.9259 - loss: 0.2275 - val_accuracy: 0.6125 - val_loss: 1.9529 - learning_rate: 3.1250e-05
# Epoch 25/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 829ms/step - accuracy: 0.9280 - loss: 0.2170 - val_accuracy: 0.6200 - val_loss: 1.9654 - learning_rate: 1.5625e-05
# Epoch 26/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 831ms/step - accuracy: 0.9241 - loss: 0.2228 - val_accuracy: 0.6200 - val_loss: 1.9623 - learning_rate: 1.5625e-05
# Epoch 27/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9431 - loss: 0.1876
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 847ms/step - accuracy: 0.9430 - loss: 0.1880 - val_accuracy: 0.6150 - val_loss: 1.9219 - learning_rate: 1.5625e-05
# Epoch 28/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 833ms/step - accuracy: 0.9359 - loss: 0.1951 - val_accuracy: 0.6175 - val_loss: 1.9348 - learning_rate: 7.8125e-06
# Epoch 29/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.9441 - loss: 0.1752
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 830ms/step - accuracy: 0.9441 - loss: 0.1752 - val_accuracy: 0.6175 - val_loss: 1.9371 - learning_rate: 7.8125e-06
# Epoch 30/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 829ms/step - accuracy: 0.9433 - loss: 0.1861 - val_accuracy: 0.6150 - val_loss: 1.9384 - learning_rate: 3.9063e-06
# Epoch 31/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 0.9425 - loss: 0.1962
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 833ms/step - accuracy: 0.9425 - loss: 0.1962 - val_accuracy: 0.6150 - val_loss: 1.9431 - learning_rate: 3.9063e-06
# Epoch 32/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 833ms/step - accuracy: 0.9313 - loss: 0.2052 - val_accuracy: 0.6175 - val_loss: 1.9414 - learning_rate: 1.9531e-06
# Epoch 33/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 0.9301 - loss: 0.1947
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 833ms/step - accuracy: 0.9302 - loss: 0.1946 - val_accuracy: 0.6175 - val_loss: 1.9418 - learning_rate: 1.9531e-06
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 25.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# C:\Users\MoeSleazy\AppData\Local\Temp\ipykernel_22348\2545126738.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plot_curves(history_ex_2, estop=estop_ex_2).show()
# Model saved to: ./model/experiment_2_model.h5

# %%
def run_experiment(make_spec, augment=0):

  images_train = np.array([make_spec(clip,sr) for clip in train_audio])
  images_test =  np.array([make_spec(clip,sr) for clip in test_audio])

  num_augmented = int(len(train_audio)*augment)
  if augment:
    #genreate augmented images from the first num_augmented clips and concatenate them to the train images
    augmented_img = np.array([make_spec(audio_augment(samples=clip, sample_rate=sr),sr) for clip in train_audio[:num_augmented]])
    images_train = np.concatenate((images_train, augmented_img))


  #expected shape (num_examples, spec freq range, spec time, 1)
  shape_train = (len(images_train), images_train[0].shape[0], images_train[0].shape[1], 1)
  shape_test = (len(images_test), images_train[0].shape[0], images_train[0].shape[1], 1)
  images_train = np.resize(images_train, shape_train)
  images_test = np.resize(images_test, shape_test)

  labels_train = np.array(train_labels+train_labels[:num_augmented])
  labels_test = np.array(test_labels)

  model = build_model(shape_train[1:])

  model.summary()

  history = model.fit(images_train, labels_train, epochs=40, validation_data=(images_test,labels_test), callbacks=[rlronp,estop])

  return history, estop

# %%
import librosa
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load the trained model
model_path = './model/experiment_2_model.h5'

def custom_load_model(model_path):
    # Load the model without loading its weights
    model = Sequential.from_config(load_model(model_path, compile=False).get_config())

    # Rebuild the model without BatchNormalization layers
    for layer in model.layers:
        if 'batch_normalization' in layer.name:
            model.add(Conv2D(filters=layer.filters,
                             kernel_size=layer.kernel_size,
                             strides=layer.strides,
                             padding=layer.padding,
                             activation='relu'))
        else:
            model.add(layer)
    
    return model

# Load the model with BatchNormalization layers replaced by Conv2D layers
model = custom_load_model(model_path)

# Define the function to preprocess audio files
def generate_mel_spectrogram(y, sr):
    melspec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    melspec = librosa.power_to_db(melspec, ref=np.max)
    return melspec

# Load and preprocess the test audio file
audio_file_path = 'output.wav'
y, sr = librosa.load(audio_file_path)
mel_spec = generate_mel_spectrogram(y, sr)

# Add batch and channel dimensions
mel_spec = mel_spec[np.newaxis, ..., np.newaxis]  # Add batch and channel dimension

# Make prediction
prediction = model.predict(mel_spec)

# Get the predicted class index
predicted_class_index = np.argmax(prediction)

# Display the prediction
print(f"Predicted Class Index: {predicted_class_index}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 28
#      25     return model
#      27 # Load the model with BatchNormalization layers replaced by Conv2D layers
# ---> 28 model = custom_load_model(model_path)
#      30 # Define the function to preprocess audio files
#      31 def generate_mel_spectrogram(y, sr):
#
# Cell In[91], line 12, in custom_load_model(model_path)
#      10 def custom_load_model(model_path):
#      11     # Load the model without loading its weights
# ---> 12     model = Sequential.from_config(load_model(model_path, compile=False).get_config())
#      14     # Rebuild the model without BatchNormalization layers
#      15     for layer in model.layers:
#
# File ~\anaconda3\lib\site-packages\keras\src\saving\saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
#     185     raise ValueError(
#     186         f"File not found: filepath={filepath}. "
#     187         "Please ensure the file is an accessible `.keras` "
#     188         "zip file."
#     189     )
#
# File ~\anaconda3\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:138, in load_model_from_hdf5(filepath, custom_objects, compile)
#     133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
# --> 138     load_weights_from_hdf5_group(f["model_weights"], model)
#     140 if compile:
#     141     # instantiate optimizer
#     142     training_config = f.attrs.get("training_config")
#
# File ~\anaconda3\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:376, in load_weights_from_hdf5_group(f, model)
#     369         raise ValueError(
#     370             f"Weight count mismatch for layer #{k} (named {layer.name} in "
#     371             f"the current model, {name} in the save file). "
#     372             f"Layer expects {len(symbolic_weights)} weight(s). Received "
#     373             f"{len(weight_values)} saved weight(s)"
#     374         )
#     375     for ref_v, val in zip(symbolic_weights, weight_values):
# --> 376         ref_v.assign(val)
#     378 if "top_level_model_weights" in f:
#     379     symbolic_weights = list(
#     380         # model.weights
#     381         v
#     382         for v in model._trainable_variables + model._non_trainable_variables
#     383         if v in model.weights
#     384     )
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\variables.py:135, in KerasVariable.assign(self, value)
#     133 value = self._convert_to_tensor(value, dtype=self.dtype)
#     134 if not shape_equal(value.shape, self.shape):
# --> 135     raise ValueError(
#     136         "The shape of the target variable and "
#     137         "the shape of the target value in "
#     138         "`variable.assign(value)` must match. "
#     139         f"variable.shape={self.value.shape}, "
#     140         f"Received: value.shape={value.shape}. "
#     141         f"Target variable: {self}"
#     142     )
#     143 if in_stateless_scope():
#     144     scope = get_stateless_scope()
#
# ValueError: The shape of the target variable and the shape of the target value in `variable.assign(value)` must match. variable.shape=(1,), Received: value.shape=(128,). Target variable: <KerasVariable shape=(1,), dtype=float32, path=sequential_11/batch_normalization_11/gamma>

# %%
# Experiment #1: Mel Spectrograms, No augmentation

def generate_mel_spectrogram(y,sr):
    melspec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    melspec = librosa.power_to_db(melspec, ref=np.max)
    return melspec

history_ex_1, estop_ex_1 = run_experiment(generate_mel_spectrogram, augment=0)
plot_curves(history_ex_1, estop=estop_ex_1).show()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization_6                │ (None, 128, 216, 1)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 128, 216, 64)        │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_20 (MaxPooling2D)      │ (None, 64, 108, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 64, 108, 128)        │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 32, 54, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 32, 54, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 16, 27, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 16, 27, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 8, 13, 256)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 26624)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │       6,816,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 50)                  │          12,850 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,789,106 (29.71 MB)
#  Trainable params: 7,788,850 (29.71 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 44s 837ms/step - accuracy: 0.0233 - loss: 4.0049 - val_accuracy: 0.0325 - val_loss: 4.7064 - learning_rate: 0.0010
# Epoch 2/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 44s 872ms/step - accuracy: 0.0873 - loss: 3.5971 - val_accuracy: 0.0950 - val_loss: 3.5109 - learning_rate: 0.0010
# Epoch 3/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 839ms/step - accuracy: 0.1651 - loss: 3.1847 - val_accuracy: 0.2425 - val_loss: 2.8763 - learning_rate: 0.0010
# Epoch 4/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 44s 878ms/step - accuracy: 0.2773 - loss: 2.6938 - val_accuracy: 0.3500 - val_loss: 2.4316 - learning_rate: 0.0010
# Epoch 5/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 813ms/step - accuracy: 0.3585 - loss: 2.3436 - val_accuracy: 0.3875 - val_loss: 2.3642 - learning_rate: 0.0010
# Epoch 6/40
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 816ms/step - accuracy: 0.4302 - loss: 2.0459 - val_accuracy: 0.4075 - val_loss: 2.1176 - learning_rate: 0.0010
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# C:\Users\MoeSleazy\AppData\Local\Temp\ipykernel_22348\1079061292.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plot_curves(history_ex_1, estop=estop_ex_1).show()

# %%
# Experiment #1: Mel Spectrograms, No augmentation

def generate_mel_spectrogram(y,sr):
    melspec = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    melspec = librosa.power_to_db(melspec, ref=np.max)
    return melspec

#history_ex_1, estop_ex_1 = run_experiment(generate_mel_spectrogram, augment=0)
#plot_curves(history_ex_1, estop=estop_ex_1).show()

# %%
history_ex_2, estop_ex_2 = run_experiment(generate_mel_spectrogram, augment=.25)

plot_curves(history_ex_2, estop=estop_ex_2).show()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization_7                │ (None, 128, 216, 1)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 128, 216, 64)        │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_24 (MaxPooling2D)      │ (None, 64, 108, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 64, 108, 128)        │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 32, 54, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (None, 32, 54, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 16, 27, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (None, 16, 27, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_27 (MaxPooling2D)      │ (None, 8, 13, 256)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 26624)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 256)                 │       6,816,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 50)                  │          12,850 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,789,106 (29.71 MB)
#  Trainable params: 7,788,850 (29.71 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 851ms/step - accuracy: 0.0232 - loss: 3.9519 - val_accuracy: 0.0325 - val_loss: 4.2702 - learning_rate: 0.0010
# Epoch 2/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 849ms/step - accuracy: 0.0966 - loss: 3.4839 - val_accuracy: 0.1500 - val_loss: 3.3331 - learning_rate: 0.0010
# Epoch 3/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 862ms/step - accuracy: 0.1990 - loss: 2.9744 - val_accuracy: 0.3100 - val_loss: 2.6508 - learning_rate: 0.0010
# Epoch 4/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 838ms/step - accuracy: 0.2731 - loss: 2.5334 - val_accuracy: 0.3850 - val_loss: 2.2767 - learning_rate: 0.0010
# Epoch 5/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 821ms/step - accuracy: 0.3770 - loss: 2.1442 - val_accuracy: 0.4500 - val_loss: 2.0747 - learning_rate: 0.0010
# Epoch 6/40
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 822ms/step - accuracy: 0.4578 - loss: 1.8432 - val_accuracy: 0.4725 - val_loss: 1.9018 - learning_rate: 0.0010
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# C:\Users\MoeSleazy\AppData\Local\Temp\ipykernel_22348\1641145142.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plot_curves(history_ex_2, estop=estop_ex_2).show()

# %%
history_ex_3, estop_ex_3 = run_experiment(generate_mel_spectrogram, augment=.5)

plot_curves(history_ex_3, estop=estop_ex_3).show()

# %%
history_ex_4, estop_ex_4 = run_experiment(generate_mel_spectrogram, augment=1)

plot_curves(history_ex_4, estop=estop_ex_4).show()

# %%
def generate_mfcc(y,sr):
  return librosa.feature.mfcc(y=y,sr=sr, n_fft=2048, hop_length=512, n_mfcc=20)

#mfcc_ex_5, estop_ex_5 = run_experiment(generate_mfcc, augment=0)
#plot_curves(mfcc_ex_5, estop=estop_ex_5).show()

# %%
#mfcc_ex_6, estop_ex_6 = run_experiment(generate_mfcc, augment=.25)

plot_curves(mfcc_ex_6).show()

# %%
mfcc_ex_7, estop_ex_7 = run_experiment(generate_mfcc, augment=.5)

plot_curves(mfcc_ex_7, estop=estop_ex_7).show()

# %%
mfcc_ex_8, estop_ex_8 = run_experiment(generate_mfcc, augment=1)

plot_curves(mfcc_ex_8, estop=estop_ex_8).show()

# %%
def generate_tempogram(y,sr):
    oenv = librosa.onset.onset_strength(y=y, sr=sr, hop_length=512)
    tempogram = librosa.feature.tempogram(onset_envelope=oenv, sr=sr, hop_length= 512, norm=None)
    return tempogram

#history_ex_9, estop_ex_9 = run_experiment(generate_tempogram, augment=0)
#plot_curves(history_ex_9, estop=estop_ex_9).show()

# %%
history_ex_10, estop_ex_10 = run_experiment(generate_tempogram, augment=.25)
plot_curves(history_ex_10, estop=estop_ex_10).show()

# %%
history_ex_11, estop_ex_11 = run_experiment(generate_tempogram, augment=.5)
plot_curves(history_ex_11, estop=estop_ex_11).show()

# %%
history_ex_12, estop_ex_12 = run_experiment(generate_tempogram, augment=1)
plot_curves(history_ex_12, estop=estop_ex_12).show()

# %%
def generate_chromagram(y,sr):
  return librosa.feature.chroma_stft(y=y,sr=sr,n_fft=2048,hop_length=512, n_chroma=24)

#history_ex_13, estop_ex_13 = run_experiment(generate_chromagram, augment=0)
#plot_curves(history_ex_13, estop=estop_ex_13).show()

# %%
history_ex_14, estop_ex_14 = run_experiment(generate_chromagram, augment=.25)
plot_curves(history_ex_14, estop=estop_ex_14).show()

# %%
history_ex_15, estop_ex_15 = run_experiment(generate_chromagram, augment=.5)
plot_curves(history_ex_15, estop=estop_ex_15).show()

# %%
history_ex_16, estop_ex_16 = run_experiment(generate_chromagram, augment=1)
plot_curves(history_ex_16, estop=estop_ex_16).show()

# %%
def make_stacked_spec(y,sr, spec_generators, scale = False):
  #make each spec
  specs = [spec_gen(y,sr) for spec_gen in spec_generators]
  #find the tallest height
  heights = np.array([spec.shape[0] for spec in specs])
  tallest = np.argmax(heights)
  stacked_specs = []
  for spec in specs:
    if scale:
      spec = np.array(Image.fromarray(spec).resize(specs[tallest].shape))
    else:
      #insert copies of the spec until it's over the tallest height
      while spec.shape[0] < specs[tallest].shape[0]:
        spec = np.vstack((spec,spec))
      #trim off the top edge
      spec = spec[0:specs[tallest].shape[0],:]
    stacked_specs.append(spec)
  # dstack each spec
  stacked_spec = np.dstack([spec for spec in stacked_specs])
  return stacked_spec

# %%
def run_experiment_stacked_specs(spec_generators, augment=0):

  num_channels = len(spec_generators)
  
  images_train = np.array([make_stacked_spec(clip,sr, spec_generators) for clip in train_audio])
  images_test =  np.array([make_stacked_spec(clip,sr, spec_generators) for clip in test_audio])

  num_augmented = int(len(train_audio)*augment)
  if augment:
    #genreate augmented images from the first num_augmented clips and concatenate them to the train images
    augmented_img = np.array([make_stacked_spec(audio_augment(samples=clip, sample_rate=sr),sr, spec_generators) for clip in train_audio[:num_augmented]])
    images_train = np.concatenate((images_train, augmented_img))


  #expected shape (num_examples, spec freq range, spec time, 1)
  shape_train = (len(images_train), images_train[0].shape[0], images_train[0].shape[1], num_channels)
  shape_test = (len(images_test), images_train[0].shape[0], images_train[0].shape[1], num_channels)
  images_train = np.resize(images_train, shape_train)
  images_test = np.resize(images_test, shape_test)

  labels_train = np.array(train_labels+train_labels[:num_augmented])
  labels_test = np.array(test_labels)

  model = build_model(shape_train[1:])

  model.summary()

  history = model.fit(images_train, labels_train, epochs=40, validation_data=(images_test,labels_test), callbacks=[rlronp,estop])

  return history, estop

# %%
#melspecs and tempograms
history_ex_17, estop_ex_17 = run_experiment_stacked_specs([generate_mel_spectrogram, generate_tempogram], augment=0)

plot_curves(history_ex_17, estop=estop_ex_17).show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_1 (Batc  (None, 384, 216, 2)      1536
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 384, 216, 64)      1216
#
#  max_pooling2d_4 (MaxPooling  (None, 192, 108, 64)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 192, 108, 128)     73856
#
#  max_pooling2d_5 (MaxPooling  (None, 96, 54, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 96, 54, 256)       295168
#
#  max_pooling2d_6 (MaxPooling  (None, 48, 27, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 48, 27, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 24, 13, 256)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 79872)             0
#
#  dense_2 (Dense)             (None, 256)               20447488
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 50)                12850
#
# =================================================================
# Total params: 21,422,194
# Trainable params: 21,421,426
# Non-trainable params: 768
# _________________________________________________________________
# Epoch 1/40
# 50/50 [==============================] - 14s 230ms/step - loss: 3.9482 - accuracy: 0.0331 - val_loss: 3.7673 - val_accuracy: 0.0300 - lr: 0.0010
# Epoch 2/40
# 50/50 [==============================] - 11s 212ms/step - loss: 3.4773 - accuracy: 0.0944 - val_loss: 3.2940 - val_accuracy: 0.1400 - lr: 0.0010
# Epoch 3/40
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 11s 218ms/step - loss: 0.3001 - accuracy: 0.9013 - val_loss: 2.3492 - val_accuracy: 0.5675 - lr: 2.5000e-04
# Epoch 20/40
# 50/50 [==============================] - 11s 220ms/step - loss: 0.2809 - accuracy: 0.9013 - val_loss: 2.2950 - val_accuracy: 0.5900 - lr: 1.2500e-04
# Epoch 21/40
# 50/50 [==============================] - 11s 219ms/step - loss: 0.2728 - accuracy: 0.9131 - val_loss: 2.3489 - val_accuracy: 0.5725 - lr: 1.2500e-04
# Epoch 22/40
# 50/50 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.9019
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 11s 219ms/step - loss: 0.2946 - accuracy: 0.9019 - val_loss: 2.2883 - val_accuracy: 0.5800 - lr: 1.2500e-04
# Epoch 23/40
# 50/50 [==============================] - 11s 220ms/step - loss: 0.2439 - accuracy: 0.9300 - val_loss: 2.3069 - val_accuracy: 0.5775 - lr: 6.2500e-05
# Epoch 24/40
# 50/50 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9287
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 11s 220ms/step - loss: 0.2173 - accuracy: 0.9287 - val_loss: 2.3461 - val_accuracy: 0.5875 - lr: 6.2500e-05
# Epoch 25/40
# 50/50 [==============================] - 11s 222ms/step - loss: 0.2456 - accuracy: 0.9150 - val_loss: 2.3410 - val_accuracy: 0.5925 - lr: 3.1250e-05
# Epoch 26/40
# 50/50 [==============================] - 11s 221ms/step - loss: 0.2258 - accuracy: 0.9256 - val_loss: 2.3317 - val_accuracy: 0.5825 - lr: 3.1250e-05
# Epoch 27/40
# 50/50 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.9369
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 11s 221ms/step - loss: 0.1975 - accuracy: 0.9369 - val_loss: 2.3677 - val_accuracy: 0.5900 - lr: 3.1250e-05
# Epoch 28/40
# 50/50 [==============================] - 11s 220ms/step - loss: 0.2163 - accuracy: 0.9300 - val_loss: 2.3772 - val_accuracy: 0.5925 - lr: 1.5625e-05
# Epoch 29/40
# 50/50 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9375
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 50/50 [==============================] - 11s 221ms/step - loss: 0.1987 - accuracy: 0.9375 - val_loss: 2.3875 - val_accuracy: 0.5900 - lr: 1.5625e-05
# Epoch 30/40
# 50/50 [==============================] - 11s 220ms/step - loss: 0.2328 - accuracy: 0.9212 - val_loss: 2.3787 - val_accuracy: 0.5900 - lr: 7.8125e-06
# Epoch 31/40
# 50/50 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9319
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Restoring model weights from the end of the best epoch: 25.
# 50/50 [==============================] - 11s 221ms/step - loss: 0.2176 - accuracy: 0.9319 - val_loss: 2.3792 - val_accuracy: 0.5925 - lr: 7.8125e-06
# Epoch 31: early stopping

# %%
#melspecs, chromagrams, and  tempograms at 100% augmentation
history_ex_17, estop_ex_17 = run_experiment_stacked_specs([generate_mel_spectrogram, generate_chromagram, generate_tempogram], augment=1)

plot_curves(history_ex_17, estop=estop_ex_17).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 384, 216, 3)      1536
#  ormalization)
#
#  conv2d (Conv2D)             (None, 384, 216, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 192, 108, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 192, 108, 128)     73856
#
#  max_pooling2d_1 (MaxPooling  (None, 96, 54, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 54, 256)       295168
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 27, 256)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 48, 27, 256)       590080
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 13, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 79872)             0
#
#  dense (Dense)               (None, 256)               20447488
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 50)                12850
#
# =================================================================
# Total params: 21,422,770
# Trainable params: 21,422,002
# Non-trainable params: 768
# _________________________________________________________________
# Epoch 1
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 100/100 [==============================] - 23s 228ms/step - loss: 0.1552 - accuracy: 0.9534 - val_loss: 2.1947 - val_accuracy: 0.6425 - lr: 2.5000e-04
# Epoch 16/40
# 100/100 [==============================] - 22s 224ms/step - loss: 0.1316 - accuracy: 0.9553 - val_loss: 2.2020 - val_accuracy: 0.6475 - lr: 1.2500e-04
# Epoch 17/40
# 100/100 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9581
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Restoring model weights from the end of the best epoch: 11.
# 100/100 [==============================] - 23s 227ms/step - loss: 0.1204 - accuracy: 0.9581 - val_loss: 2.2113 - val_accuracy: 0.6425 - lr: 1.2500e-04
# Epoch 17: early stopping

# %%
#melspecs and  chromagrams at 100% augmentation
history_ex_19, estop_ex_19 = run_experiment_stacked_specs([generate_mel_spectrogram, generate_chromagram], augment=1)

plot_curves(history_ex_19, estop=estop_ex_19).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 128, 216, 2)      512
#  ormalization)
#
#  conv2d (Conv2D)             (None, 128, 216, 64)      1216
#
#  max_pooling2d (MaxPooling2D  (None, 64, 108, 64)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 108, 128)      73856
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 54, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 54, 256)       295168
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 27, 256)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 27, 256)       590080
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 13, 256)       0
#  2D)
#
#  flatten (Flatten)           (None, 26624)             0
#
#  dense (Dense)               (None, 256)               6816000
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 50)                12850
#
# =================================================================
# Total params: 7,789,682
# Trainable params: 7,789,426
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 100/100 [==============================] - 15s 105ms/step - loss: 3.7134 - accuracy: 0.0616 - val_loss: 3.5138 - val_accuracy: 0.0900 - lr: 0.0010
# Epoch 2/40
# 100/100 [==============================] - 12s 121ms/step - loss: 2.9549 - accuracy: 0.2081 - val_loss: 2.6036 - val_accuracy: 0.3025 - lr: 0.0010
# Epoch 3/40
# 100/100 [==============================] - 10s 103ms/step - loss: 2.3166 - accuracy: 0.3525 - val_loss: 2.0596 - val_accuracy: 0.4700 - lr: 0.0010
# Epoch 4/40
# 100/100 [==============================] - 10s 101ms/step - loss: 1.8161 - accuracy: 0.4866 - val_loss: 1.7935 - val_accuracy: 0.5150 - lr: 0.0010
# Epoch 5/40
# 100/100 [==============================] - 11s 108ms/step - loss: 1.4728 - accuracy: 0.5675 - val_loss: 1.6289 - val_accuracy: 0.5475 - lr: 0.0010
# Epoch 6/40
# 100/100 [==============================] - 10s 102ms/step - loss: 1.1413 - accuracy: 0.6662 - val_loss: 1.6578 - val_accuracy: 0.5300 - lr: 0.0010
# Epoch 7/40
# 100/100 [==============================] - 11s 114ms/step - loss: 0.8874 - accuracy: 0.7303 - val_loss: 1.6664 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 8/40
# 100/100 [==============================] - 11s 106ms/step - loss: 0.7207 - accuracy: 0.7750 - val_loss: 1.6986 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 9/40
# 100/100 [==============================] - 11s 109ms/step - loss: 0.6395 - accuracy: 0.8016 - val_loss: 1.7383 - val_accuracy: 0.5725 - lr: 0.0010
# Epoch 10/40
# 100/100 [==============================] - 11s 112ms/step - loss: 0.5301 - accuracy: 0.8459 - val_loss: 1.8522 - val_accuracy: 0.5850 - lr: 0.0010
# Epoch 11/40
# 100/100 [==============================] - 10s 102ms/step - loss: 0.